# %% [markdown]
# # Data Analysis with Python
# - Basic data analysis using python programming language.
#
# ## Data Types
# ### Qualitative Data
# - represents the characteristics of the value.
# - doesn't have mathematical meaning.
# #### Types of Qualitative Data
# - Nominal : No quantitative value and meaning wouldn't change.
# - Ordinal : Has order and it's usually measured by non-numeric features.
# ### Quantitative Data
# - numerical data
# - value is measured
# #### Types of Quantitative Data
# - Discrete : values are distinct and seperated. This data can be only counted.
# - Continuous : values are continuous and can only be measured.

# %%
import pandas as pd

# importing csv with pd
mv_data = pd.read_csv('bestsellers.csv')

# show first 10 data
# mv_data.head(10)

# show last 10 data
# mv_data.tail(10)

# display shape, no. of col. and rows in the data
mv_data.shape
# Out:
# (375, 8)

# %%
# display null values

# mv_data[mv_data['Date'].isna()]
mv_data = mv_data.dropna()
mv_data.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# Type           0
# dtype: int64

# %%
# summary statistics for all numeric columns
mv_data.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   347.000000    347.000000  347.000000   347.000000
# mean      4.607493   9709.674352   13.095101  2013.786744
# std       0.227582  10831.206514   10.093187     3.360868
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   3384.500000    8.000000  2011.000000
# 50%       4.600000   6310.000000   12.000000  2014.000000
# 75%       4.800000  11259.500000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
# Sorting the dataframe.
mv_data = mv_data.sort_values(by='User Rating', ascending=False)
mv_data.head(10)
# Out:
#                                                   Name                Author  \
# 128                           Hamilton: The Revolution    Lin-Manuel Miranda
# 216  Rush Revere and the Brave Pilgrims: Time-Trave...         Rush Limbaugh
# 135  Harry Potter and the Sorcerer's Stone: The Ill...          J.K. Rowling
# 134  Harry Potter and the Prisoner of Azkaban: The ...          J.K. Rowling
# 133  Harry Potter and the Goblet of Fire: The Illus...         J. K. Rowling
# 130  Harry Potter and the Chamber of Secrets: The I...          J.K. Rowling
# 80   Dog Man and Cat Kid: From the Creator of Capta...            Dav Pilkey
# 43            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 124  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 217  Rush Revere and the First Patriots: Time-Trave...         Rush Limbaugh
#
#      User Rating  Reviews  Price    Year        Genre         Type
# 128          4.9   5867.0   54.0  2016.0  Non Fiction  Non Fiction
# 216          4.9   7150.0   12.0  2013.0      Fiction      Fiction
# 135          4.9  10052.0   22.0  2016.0      Fiction      Fiction
# 134          4.9   3146.0   30.0  2017.0      Fiction      Fiction
# 133          4.9   7758.0   18.0  2019.0      Fiction      Fiction
# 130          4.9  19622.0   30.0  2016.0      Fiction      Fiction
# 80           4.9   5062.0    6.0  2018.0      Fiction      Fiction
# 43           4.9  14344.0    5.0  2017.0      Fiction      Fiction
# 124          4.9   7038.0    7.0  2012.0      Fiction      Fiction
# 217          4.9   3836.0   12.0  2014.0      Fiction      Fiction

# %%
# aggregating the dataframe - series

mv_data.groupby('Name')['Genre'].sum()
# Out:
# Name
# 10-Day Green Smoothie Cleanse                                                             Non Fiction
# 11/22/63: A Novel                                                                             Fiction
# 12 Rules for Life: An Antidote to Chaos                                                   Non Fiction
# 1984 (Signet Classics)                                                                        Fiction
# 5,000 Awesome Facts (About Everything!) (National Geographic Kids)                        Non Fiction
#                                                                                              ...
# Winter of the World: Book Two of the Century Trilogy                                          Fiction
# Women Food and God: An Unexpected Path to Almost Everything                               Non Fiction
# Wonder                                                                                        Fiction
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                                                  Fiction
# You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life    Non Fiction
# Name: Genre, Length: 347, dtype: object

# %%
# aggregating the dataframe - dataframe

mv_data.groupby('Name', as_index=False).agg({'Genre':'sum'})
# Out:
#                                                   Name        Genre
# 0                        10-Day Green Smoothie Cleanse  Non Fiction
# 1                                    11/22/63: A Novel      Fiction
# 2              12 Rules for Life: An Antidote to Chaos  Non Fiction
# 3                               1984 (Signet Classics)      Fiction
# 4    5,000 Awesome Facts (About Everything!) (Natio...  Non Fiction
# ..                                                 ...          ...
# 342  Winter of the World: Book Two of the Century T...      Fiction
# 343  Women Food and God: An Unexpected Path to Almo...  Non Fiction
# 344                                             Wonder      Fiction
# 345       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Fiction
# 346  You Are a Badass: How to Stop Doubting Your Gr...  Non Fiction
#
# [347 rows x 2 columns]

# %%
# Creating new colum

mv_data['User Rating %'] = mv_data['User Rating'] / 5 * 100
mv_data.head()
# Out:
#                                                   Name              Author  \
# 128                           Hamilton: The Revolution  Lin-Manuel Miranda
# 216  Rush Revere and the Brave Pilgrims: Time-Trave...       Rush Limbaugh
# 135  Harry Potter and the Sorcerer's Stone: The Ill...        J.K. Rowling
# 134  Harry Potter and the Prisoner of Azkaban: The ...        J.K. Rowling
# 133  Harry Potter and the Goblet of Fire: The Illus...       J. K. Rowling
#
#      User Rating  Reviews  Price    Year        Genre         Type  \
# 128          4.9   5867.0   54.0  2016.0  Non Fiction  Non Fiction
# 216          4.9   7150.0   12.0  2013.0      Fiction      Fiction
# 135          4.9  10052.0   22.0  2016.0      Fiction      Fiction
# 134          4.9   3146.0   30.0  2017.0      Fiction      Fiction
# 133          4.9   7758.0   18.0  2019.0      Fiction      Fiction
#
#      User Rating %
# 128           98.0
# 216           98.0
# 135           98.0
# 134           98.0
# 133           98.0

# %%
mv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         347 non-null    object
#  1   Author       347 non-null    object
#  2   User Rating  347 non-null    float64
#  3   Reviews      347 non-null    float64
#  4   Price        347 non-null    float64
#  5   Year         347 non-null    float64
#  6   Genre        347 non-null    object
#  7   Type         347 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 23.6+ KB

# %%
mv_data.isnull().sum()
# Out:
# Name           28
# Author         28
# User Rating    28
# Reviews        28
# Price          28
# Year           28
# Genre          28
# Type           28
# dtype: int64

# %%
mv_data[mv_data['Type'].isna()]
# Out:
#     Name Author  User Rating  Reviews  Price  Year Genre Type
# 1    NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 11   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 15   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 22   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 26   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 33   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 40   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 46   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 50   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 53   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 57   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 66   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 69   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 73   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 83   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 95   NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 123  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 131  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 165  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 183  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 211  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 230  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 240  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 247  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 281  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 286  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 307  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
# 335  NaN    NaN          NaN      NaN    NaN   NaN   NaN  NaN
